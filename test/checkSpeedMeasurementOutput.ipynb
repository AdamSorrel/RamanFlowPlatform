# %%
import numpy as np
import pandas as pd

# %%
ch1 =  [118898252475, 
        118898652875, 
        120244800833, 
        120245201234,
        120245601634, 
        120246002035, 
        120808014194, 
        120808414594, 
        120808814995, 
        120809215395]
ch1
# Out:
# [118898252475,
#  118898652875,
#  120244800833,
#  120245201234,
#  120245601634,
#  120246002035,
#  120808014194,
#  120808414594,
#  120808814995,
#  120809215395]

# %%
ch2 = [119451256433,
       119451656834, 
       119452057234, 
       119452457635, 
       119452858035,
       119453258435, 
       120808014194, 
       120808414595, 
       120808814995, 
       120809215395]
ch2
# Out:
# [119451256433,
#  119451656834,
#  119452057234,
#  119452457635,
#  119452858035,
#  119453258435,
#  120808014194,
#  120808414595,
#  120808814995,
#  120809215395]

# %%
ch2[-1]
# Out:
# 120809215395

# %%
ch1[-1]
# Out:
# 120809215395

# %%
ch2[-1] - ch1[-1]

# %%
pkVect1 = [118898252475, 
           118898652875, 
           120244800833, 
           120245201234, 
           120245601634,
           120246002035, 
           120808014194, 
           120808414594, 
           120808814995, 
           120809215395]
pkVect2 = [119451656833, 
           119452057234, 
           119452457634, 
           119452858035, 
           119453258435,
           119453658835, 
           120808414594, 
           120808814995, 
           120809215395, 
           120809615795]

#[daqThread/speedMeasurement] 0.2402

# %%
pkVect2[-1]
# Out:
# 120809615795

# %%
pkVect1[-1]
# Out:
# 120809215395

# %%
pkVect2[-1] - pkVect1[-1]
# Out:
# 400400

# %%
pkVect2[-1] - pkVect1[-2]
# Out:
# 800800

# %%
pkVect2[-1] - pkVect1[-3]
# Out:
# 1201201

# %%
pkVect2[-1] - pkVect1[-4]
# Out:
# 1601601
